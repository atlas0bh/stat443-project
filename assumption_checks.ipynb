# %% [markdown]
# so what are our assumptions
#
# 1) I assume that our model will have # total number of cases = sum # of cases in each subclass
# 2) we assume that our model is usefull
# 3) we assume that can derive the mean lambda by a vector mult as opposed to the sum of the

# %%
df = read.csv(file = './data/fluview_clean/ilinet_clean.csv')


# so there are catagories and sub catagories 
# we have the age groups
# age_0_4, 
# age_5_24
# age 25_64
    # age_25_49
    # age_50_64
# age_65
# this split happens at week 40 in 2009 so before age 25_49 and 50_64 are not accounted for
# but noting this age_25_64 is actually exactly the sum of these two age groups we can reconstruct it by taking it to be a point where there lambda value is diverted!

# so what we will do in our model is rather simple we will use the same lambda t for the forecast the age groups for that time and then after that time we will basically split it as if each one had had the distribution up to that point?
# wait that does not make sense as we will be wayyy over predicting



df
# df$age
# Out:
#      region_type region year week percent_weighted_ili percent_unweighted_ili
# 1    National    NA     1997 40   1.101480             1.216860
# 2    National    NA     1997 41   1.200070             1.280640
# 3    National    NA     1997 42   1.378760             1.239060
# 4    National    NA     1997 43   1.199200             1.144730
# 5    National    NA     1997 44   1.656180             1.261120
# 6    National    NA     1997 45   1.413260             1.282750
# 7    National    NA     1997 46   1.986800             1.445790
# 8    National    NA     1997 47   2.447490             1.647960
# 9    National    NA     1997 48   1.739010             1.675170
# 10   National    NA     1997 49   1.939190             1.617390
# 11   National    NA     1997 50   2.281660             1.766320
# 12   National    NA     1997 51   2.507610             2.103980
# 13   National    NA     1997 52   4.113520             3.136550
# ...

# %%
# now we need to check that we can roughly estimate
